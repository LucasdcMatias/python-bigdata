# %%
# importar a biblioteca pandas
import pandas as pd

# %%
# ler o arquivo super_store.csv
vendas = pd.read_csv(r'/content/drive/MyDrive/Aula dia 21 08 - Valor Lojas/super_store.csv')
# apresentar os dados
display(df)

# %%
# visualizar as colunas
print(vendas.columns)

# %%
vendas.describe()

# %%
cep_ausentes = vendas[vendas['Postal Code'].isna()]
cep_ausentes

# %%
opcao_excluir = vendas[vendas['Postal Code'].notna()].copy()
opcao_excluir.describe()

# %% [markdown]
# Opção 2: Preencha os valores ausentes com um valor padrão
#
# Burlington em Vermont - 05401

# %%
opcao_2 = vendas.copy()
opcao_2.loc[opcao_2['Postal Code'].isna(),['Postal Code']] = '05401'
opcao_2['Postal Code'].describe()
